# %% [markdown]
# # Experiment 1: Environment Setup & Package Version Verification
#
# This experiment verifies the installation and versions of essential Data Analysis and Visualization libraries.

# %%
import numpy as np
import pandas as pd
import matplotlib
import jupyterlab

packages = [
    ("NumPy", "numpy"),
    ("Pandas", "pandas"),
    ("Matplotlib", "matplotlib"),
    ("Seaborn", "seaborn"),
    ("Statsmodels", "statsmodels.api"),
    ("SciPy", "scipy"),
    ("Plotly", "plotly"),
    ("Bokeh", "bokeh"),
    ("JupyterLab", "jupyterlab"),
]

for name, pkg_name in packages:
    try:
        mod = __import__(pkg_name, fromlist=["__version__"])
        ver = getattr(mod, "__version__", getattr(mod, "version", "Unknown"))
        print(f"{name} Version: {ver}")
    except ImportError:
        print(f"{name} Version: Not installed")
# Out:
# NumPy Version: 2.2.6
# Pandas Version: 2.3.3
# Matplotlib Version: 3.10.3
# Seaborn Version: Not installed
# Statsmodels Version: Not installed
# SciPy Version: Not installed
# Plotly Version: Not installed
# Bokeh Version: Not installed
# JupyterLab Version: 4.5.1
