# %% [markdown]
# # Experiment 6: Statistical Analysis Using Diabetes Datasets - Univariate Analysis
#
# **AIM:**
# To analyze the Diabetes dataset from UCI and the Pima Indians Diabetes dataset using univariate statistical methods, including Frequency, Mean, Median, Mode, Variance, Standard Deviation, Skewness, and Kurtosis.
#
# **REQUIREMENTS:**
# - Python: Version 3.13.2
# - Jupyter Notebook: Version 7.3.2
# - Pandas, NumPy, and SciPy Libraries
#
# ---
# ### THEORY:
# - **Python**: An interpreted, general-purpose, high-level programming language with easy syntax and dynamic semantics.
# - **Jupyter Notebook**: An interactive environment that allows executing Python code cell-by-cell.
# - **NumPy**: Fundamental library for numerical computing in Python, providing support for arrays and linear algebra operations.
# - **Pandas**: Data manipulation and analysis library providing efficient data structures like DataFrame and Series.
# - **SciPy**: Scientific computing library built on NumPy, offering advanced statistical functions (`skew`, `kurtosis`).
# - **Univariate Analysis**: Involves examining each variable separately to understand its distribution, central tendency, and variability.
#   1. **Mean**: The average value.
#   2. **Median**: The middle value when sorted.
#   3. **Mode**: The most frequent value.
#   4. **Variance**: Measures data spread.
#   5. **Standard Deviation**: Square root of variance.
#   6. **Skewness**: Measures asymmetry of distribution.
#   7. **Kurtosis**: Measures the heaviness of data tails.
# - **UCI Diabetes Dataset & Pima Indians Diabetes Dataset**: Datasets containing health metrics (Glucose, BloodPressure, SkinThickness, Insulin, BMI, DiabetesPedigreeFunction, Age, Outcome).

# %% [markdown]
# ## 1. Import Libraries & Load Datasets
#
# Import `pandas`, `numpy`, and `scipy.stats` (`skew`, `kurtosis`). Read `uci_diabetes.csv` and `pima_diabetes.csv`.

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew, kurtosis

# Import Datasets
uci_diabetes = pd.read_csv('uci_diabetes.csv')
pima_diabetes = pd.read_csv('pima_diabetes.csv')

# Display Dataset Samples
print("UCI Diabetes Dataset Sample:")
print(uci_diabetes.head())
print("\nPima Indians Diabetes Dataset Sample:")
print(pima_diabetes.head())
# Out:
# UCI Diabetes Dataset Sample:
#    Glucose  BloodPressure  SkinThickness  Insulin        BMI  DiabetesPedigreeFunction  Age  Outcome
# 0       90             72             16      264  22.273511                  1.162896   79        0
# 1      162             61             34      143  41.814986                  2.158993   35        0
# 2      184             76             25      128  36.309833                  1.411238   31        0
# 3      119             83             20      230  27.258685                  1.202206   28        1
# 4      175            101             30       63  41.493982                  0.214888   59        1
#
# Pima Indians Diabetes Dataset Sample:
#    Glucose  BloodPressure  SkinThickness  Insulin        BMI  DiabetesPedigreeFunction  Age  Outcome
# 0       81             97             15      289  27.062801                  0.797425   62        1
# 1      172             50             24      229  18.588741                  0.652107   21        1
# ...

# %% [markdown]
# ## 2. Define Univariate Analysis Function & Compute Statistical Measures
#
# Calculate Mean, Median, Mode, Variance, Standard Deviation, Skewness, and Kurtosis across numerical columns.

# %%
# Define Relevant Numerical Columns
numerical_columns = [
    "Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI",
    "DiabetesPedigreeFunction", "Age"
]

# Univariate Analysis Function
def univariate_analysis(df, columns):
    stats = {}
    for col in columns:
        stats[col] = {
            "Mean": np.mean(df[col]),
            "Median": np.median(df[col]),
            "Mode": df[col].mode()[0],
            "Variance": np.var(df[col], ddof=1),
            "Standard Deviation": np.std(df[col], ddof=1),
            "Skewness": skew(df[col]),
            "Kurtosis": kurtosis(df[col])
        }
    return pd.DataFrame(stats).T

# Perform Univariate Analysis
uci_stats = univariate_analysis(uci_diabetes, numerical_columns)
pima_stats = univariate_analysis(pima_diabetes, numerical_columns)

# Display Results
print("\nUCI Diabetes Dataset Statistics:")
print(uci_stats)
print("\nPima Indians Diabetes Dataset Statistics:")
print(pima_stats)
# Out:
# UCI Diabetes Dataset Statistics:
#                                 Mean      Median        Mode     Variance  Standard Deviation  Skewness  Kurtosis
# Glucose                   137.360000  145.000000  111.000000  1296.212525           36.002952 -0.108805 -1.207990
# BloodPressure              82.920000   82.500000   63.000000   375.710707           19.383258  0.103961 -1.109669
# SkinThickness              29.190000   30.000000   39.000000   149.226162           12.215816 -0.015351 -1.253625
# Insulin                   146.480000  142.000000  290.000000  8638.433939           92.943176  0.059713 -1.328102
# BMI                        30.990932   30.298310   18.528511    61.552668            7.845551  0.103161 -1.201466
# DiabetesPedigreeFunction    1.361102    1.235436    0.103784     0.446842            0.668462  0.069207 -1.009261
# Age                        52.860000   58.000000   70.000000   317.778182           17.826334 -0.299535 -1.232924
#
#
# ...

# %% [markdown]
# ## 3. Result
#
# The univariate analysis of the UCI Diabetes and Pima Indians Diabetes datasets reveals differences in central tendency, dispersion, and distribution. Variations in skewness and kurtosis indicate differences in data patterns between the datasets.
